# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/point_history_classifier/point_history.csv'
model_save_path = 'model/point_history_classifier/point_history_classifier.hdf5'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 7

# %% [markdown]
# # 入力長

# %%
TIME_STEPS = 16
DIMENSION = 2

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築

# %%
use_lstm = True
model = None

if use_lstm:
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
        tf.keras.layers.Reshape((TIME_STEPS, DIMENSION), input_shape=(TIME_STEPS * DIMENSION, )), 
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(16, input_shape=[TIME_STEPS, DIMENSION]),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
else:
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(24, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 16, 2)             0
#
#  dropout (Dropout)           (None, 16, 2)             0
#
#  lstm (LSTM)                 (None, 16)                1216
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 10)                170
#
#  dense_1 (Dense)             (None, 7)                 77
#
# =================================================================
# Total params: 1,463
# Trainable params: 1,463
# Non-trainable params: 0
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 1/2 [==============>...............] - ETA: 2s - loss: 1.9507 - accuracy: 0.0078
# Epoch 1: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 3s 789ms/step - loss: 1.9471 - accuracy: 0.1737 - val_loss: 1.9408 - val_accuracy: 0.2911
# Epoch 2/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9378 - accuracy: 0.2812
# Epoch 2: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 1.9383 - accuracy: 0.3093 - val_loss: 1.9335 - val_accuracy: 0.2911
# Epoch 3/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9329 - accuracy: 0.3359
# Epoch 3: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 262ms/step - loss: 1.9310 - accuracy: 0.3347 - val_loss: 1.9256 - val_accuracy: 0.2785
# Epoch 4/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9234 - accuracy: 0.3047
# Epoch 4: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.9239 - accuracy: 0.3475 - val_loss: 1.9175 - val_accuracy: 0.3165
# Epoch 5/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9170 - accuracy: 0.3438
# Epoch 5: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.9164 - accuracy: 0.3771 - val_loss: 1.9090 - val_accuracy: 0.3038
# Epoch 6/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9074 - accuracy: 0.3359
# Epoch 6: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 1.9063 - accuracy: 0.3729 - val_loss: 1.9002 - val_accuracy: 0.3038
# Epoch 7/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.9031 - accuracy: 0.3125
# Epoch 7: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.8994 - accuracy: 0.3475 - val_loss: 1.8908 - val_accuracy: 0.3165
# Epoch 8/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8906 - accuracy: 0.3438
# Epoch 8: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 1.8896 - accuracy: 0.3051 - val_loss: 1.8809 - val_accuracy: 0.3418
# Epoch 9/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8867 - accuracy: 0.3594
# Epoch 9: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.8805 - accuracy: 0.3644 - val_loss: 1.8703 - val_accuracy: 0.3544
# Epoch 10/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8722 - accuracy: 0.2891
# Epoch 10: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 1.8702 - accuracy: 0.3178 - val_loss: 1.8589 - val_accuracy: 0.3544
# Epoch 11/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8554 - accuracy: 0.3906
# Epoch 11: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 97ms/step - loss: 1.8559 - accuracy: 0.3644 - val_loss: 1.8464 - val_accuracy: 0.3544
# Epoch 12/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8482 - accuracy: 0.3125
# Epoch 12: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.8462 - accuracy: 0.3517 - val_loss: 1.8327 - val_accuracy: 0.3544
# Epoch 13/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8313 - accuracy: 0.4531
# Epoch 13: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.8303 - accuracy: 0.4280 - val_loss: 1.8176 - val_accuracy: 0.3544
# Epoch 14/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8301 - accuracy: 0.3750
# Epoch 14: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 1.8205 - accuracy: 0.4110 - val_loss: 1.8007 - val_accuracy: 0.3544
# Epoch 15/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.8011 - accuracy: 0.4219
# Epoch 15: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.7995 - accuracy: 0.3771 - val_loss: 1.7819 - val_accuracy: 0.3544
# Epoch 16/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7841 - accuracy: 0.3906
# Epoch 16: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 86ms/step - loss: 1.7838 - accuracy: 0.3898 - val_loss: 1.7606 - val_accuracy: 0.3544
# Epoch 17/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7606 - accuracy: 0.3906
# Epoch 17: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 90ms/step - loss: 1.7583 - accuracy: 0.4025 - val_loss: 1.7367 - val_accuracy: 0.3797
# Epoch 18/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7380 - accuracy: 0.4531
# Epoch 18: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 84ms/step - loss: 1.7346 - accuracy: 0.4364 - val_loss: 1.7096 - val_accuracy: 0.3797
# Epoch 19/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.7119 - accuracy: 0.4531
# Epoch 19: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.7066 - accuracy: 0.4661 - val_loss: 1.6784 - val_accuracy: 0.3797
# Epoch 20/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6728 - accuracy: 0.4297
# Epoch 20: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 1.6674 - accuracy: 0.4153 - val_loss: 1.6424 - val_accuracy: 0.3671
# Epoch 21/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6688 - accuracy: 0.3281
# Epoch 21: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 1.6453 - accuracy: 0.3686 - val_loss: 1.6010 - val_accuracy: 0.3418
# Epoch 22/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.6072 - accuracy: 0.4297
# Epoch 22: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.5946 - accuracy: 0.4407 - val_loss: 1.5535 - val_accuracy: 0.3418
# Epoch 23/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5679 - accuracy: 0.4141
# Epoch 23: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 93ms/step - loss: 1.5505 - accuracy: 0.4110 - val_loss: 1.4995 - val_accuracy: 0.3544
# Epoch 24/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5231 - accuracy: 0.3750
# Epoch 24: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 1.5030 - accuracy: 0.3729 - val_loss: 1.4393 - val_accuracy: 0.3165
# Epoch 25/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.4577 - accuracy: 0.4922
# Epoch 25: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.4404 - accuracy: 0.4746 - val_loss: 1.3742 - val_accuracy: 0.3038
# Epoch 26/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3842 - accuracy: 0.4531
# Epoch 26: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.3753 - accuracy: 0.4237 - val_loss: 1.3065 - val_accuracy: 0.3038
# Epoch 27/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.3187 - accuracy: 0.3906
# Epoch 27: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 1.3217 - accuracy: 0.3559 - val_loss: 1.2398 - val_accuracy: 0.3038
# Epoch 28/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2755 - accuracy: 0.3281
# Epoch 28: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 82ms/step - loss: 1.2662 - accuracy: 0.3263 - val_loss: 1.1775 - val_accuracy: 0.3038
# Epoch 29/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.2406 - accuracy: 0.3359
# Epoch 29: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2191 - accuracy: 0.3644 - val_loss: 1.1222 - val_accuracy: 0.3038
# Epoch 30/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1945 - accuracy: 0.3984
# Epoch 30: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 1.1716 - accuracy: 0.4025 - val_loss: 1.0745 - val_accuracy: 0.3038
# Epoch 31/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0976 - accuracy: 0.4375
# Epoch 31: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.1173 - accuracy: 0.4153 - val_loss: 1.0339 - val_accuracy: 0.3038
# Epoch 32/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0655 - accuracy: 0.4375
# Epoch 32: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0940 - accuracy: 0.3686 - val_loss: 0.9989 - val_accuracy: 0.3038
# Epoch 33/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1172 - accuracy: 0.3984
# Epoch 33: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0613 - accuracy: 0.4025 - val_loss: 0.9689 - val_accuracy: 0.3797
# Epoch 34/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0338 - accuracy: 0.4453
# Epoch 34: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0322 - accuracy: 0.4407 - val_loss: 0.9430 - val_accuracy: 0.6329
# Epoch 35/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0091 - accuracy: 0.5312
# Epoch 35: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.9784 - accuracy: 0.5466 - val_loss: 0.9213 - val_accuracy: 0.6329
# Epoch 36/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0132 - accuracy: 0.5703
# Epoch 36: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9871 - accuracy: 0.5297 - val_loss: 0.9036 - val_accuracy: 0.6329
# Epoch 37/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9302 - accuracy: 0.6016
# Epoch 37: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.9338 - accuracy: 0.5805 - val_loss: 0.8896 - val_accuracy: 0.6329
# Epoch 38/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9038 - accuracy: 0.5703
# Epoch 38: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.9040 - accuracy: 0.5847 - val_loss: 0.8792 - val_accuracy: 0.6329
# Epoch 39/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8894 - accuracy: 0.6562
# Epoch 39: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.9057 - accuracy: 0.6229 - val_loss: 0.8719 - val_accuracy: 0.6329
# Epoch 40/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8874 - accuracy: 0.6406
# Epoch 40: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8701 - accuracy: 0.6398 - val_loss: 0.8672 - val_accuracy: 0.6329
# Epoch 41/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9553 - accuracy: 0.5859
# Epoch 41: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.9177 - accuracy: 0.6102 - val_loss: 0.8641 - val_accuracy: 0.6329
# Epoch 42/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9491 - accuracy: 0.5625
# Epoch 42: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.9022 - accuracy: 0.6102 - val_loss: 0.8622 - val_accuracy: 0.6329
# Epoch 43/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8674 - accuracy: 0.5938
# Epoch 43: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8875 - accuracy: 0.6144 - val_loss: 0.8611 - val_accuracy: 0.6329
# Epoch 44/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8655 - accuracy: 0.6719
# Epoch 44: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8584 - accuracy: 0.6356 - val_loss: 0.8603 - val_accuracy: 0.6329
# Epoch 45/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8616 - accuracy: 0.6562
# Epoch 45: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8901 - accuracy: 0.6525 - val_loss: 0.8594 - val_accuracy: 0.6329
# Epoch 46/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8353 - accuracy: 0.6875
# Epoch 46: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9220 - accuracy: 0.6186 - val_loss: 0.8584 - val_accuracy: 0.6329
# Epoch 47/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9562 - accuracy: 0.5781
# Epoch 47: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9329 - accuracy: 0.6398 - val_loss: 0.8566 - val_accuracy: 0.6329
# Epoch 48/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9491 - accuracy: 0.5781
# Epoch 48: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8511 - accuracy: 0.6398 - val_loss: 0.8548 - val_accuracy: 0.6329
# Epoch 49/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8454 - accuracy: 0.6406
# Epoch 49: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8972 - accuracy: 0.6186 - val_loss: 0.8531 - val_accuracy: 0.6329
# Epoch 50/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9110 - accuracy: 0.6094
# Epoch 50: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8845 - accuracy: 0.6356 - val_loss: 0.8513 - val_accuracy: 0.6329
# Epoch 51/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8495 - accuracy: 0.6484
# Epoch 51: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8739 - accuracy: 0.6398 - val_loss: 0.8496 - val_accuracy: 0.6329
# Epoch 52/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8525 - accuracy: 0.6484
# Epoch 52: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8430 - accuracy: 0.6483 - val_loss: 0.8479 - val_accuracy: 0.6329
# Epoch 53/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9312 - accuracy: 0.6250
# Epoch 53: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8961 - accuracy: 0.6483 - val_loss: 0.8464 - val_accuracy: 0.6329
# Epoch 54/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8819 - accuracy: 0.6250
# Epoch 54: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8813 - accuracy: 0.6356 - val_loss: 0.8451 - val_accuracy: 0.6329
# Epoch 55/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8667 - accuracy: 0.6328
# Epoch 55: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8583 - accuracy: 0.6398 - val_loss: 0.8440 - val_accuracy: 0.6329
# Epoch 56/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8962 - accuracy: 0.5625
# Epoch 56: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8868 - accuracy: 0.6144 - val_loss: 0.8431 - val_accuracy: 0.6329
# Epoch 57/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8063 - accuracy: 0.5938
# Epoch 57: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8517 - accuracy: 0.6271 - val_loss: 0.8423 - val_accuracy: 0.6329
# Epoch 58/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9043 - accuracy: 0.6094
# Epoch 58: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8339 - accuracy: 0.6441 - val_loss: 0.8415 - val_accuracy: 0.6329
# Epoch 59/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8316 - accuracy: 0.6172
# Epoch 59: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8251 - accuracy: 0.6483 - val_loss: 0.8408 - val_accuracy: 0.6329
# Epoch 60/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8657 - accuracy: 0.5625
# Epoch 60: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8572 - accuracy: 0.6102 - val_loss: 0.8402 - val_accuracy: 0.6329
# Epoch 61/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8862 - accuracy: 0.6172
# Epoch 61: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8693 - accuracy: 0.6356 - val_loss: 0.8395 - val_accuracy: 0.6329
# Epoch 62/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8755 - accuracy: 0.6250
# Epoch 62: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.8671 - accuracy: 0.6314 - val_loss: 0.8389 - val_accuracy: 0.6329
# Epoch 63/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8853 - accuracy: 0.5781
# Epoch 63: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8809 - accuracy: 0.6144 - val_loss: 0.8384 - val_accuracy: 0.6329
# Epoch 64/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9285 - accuracy: 0.6328
# Epoch 64: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8857 - accuracy: 0.6356 - val_loss: 0.8378 - val_accuracy: 0.6329
# Epoch 65/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7829 - accuracy: 0.6641
# Epoch 65: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8251 - accuracy: 0.6186 - val_loss: 0.8374 - val_accuracy: 0.6329
# Epoch 66/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7537 - accuracy: 0.6562
# Epoch 66: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8297 - accuracy: 0.6441 - val_loss: 0.8370 - val_accuracy: 0.6329
# Epoch 67/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8318 - accuracy: 0.6406
# Epoch 67: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8329 - accuracy: 0.6356 - val_loss: 0.8366 - val_accuracy: 0.6329
# Epoch 68/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8016 - accuracy: 0.6562
# Epoch 68: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8239 - accuracy: 0.6314 - val_loss: 0.8363 - val_accuracy: 0.6329
# Epoch 69/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7670 - accuracy: 0.6719
# Epoch 69: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8174 - accuracy: 0.6525 - val_loss: 0.8360 - val_accuracy: 0.6329
# Epoch 70/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8721 - accuracy: 0.5703
# Epoch 70: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8736 - accuracy: 0.6144 - val_loss: 0.8357 - val_accuracy: 0.6329
# Epoch 71/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8642 - accuracy: 0.6016
# Epoch 71: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8543 - accuracy: 0.6186 - val_loss: 0.8353 - val_accuracy: 0.6329
# Epoch 72/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8548 - accuracy: 0.6172
# Epoch 72: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8442 - accuracy: 0.6271 - val_loss: 0.8349 - val_accuracy: 0.6329
# Epoch 73/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8777 - accuracy: 0.6172
# Epoch 73: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.8340 - accuracy: 0.6271 - val_loss: 0.8345 - val_accuracy: 0.6329
# Epoch 74/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8829 - accuracy: 0.6250
# Epoch 74: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8408 - accuracy: 0.6398 - val_loss: 0.8342 - val_accuracy: 0.6329
# Epoch 75/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8035 - accuracy: 0.6406
# Epoch 75: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8285 - accuracy: 0.6441 - val_loss: 0.8340 - val_accuracy: 0.6329
# Epoch 76/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7580 - accuracy: 0.6406
# Epoch 76: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.8347 - accuracy: 0.6314 - val_loss: 0.8338 - val_accuracy: 0.6329
# Epoch 77/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8266 - accuracy: 0.6875
# Epoch 77: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 123ms/step - loss: 0.8558 - accuracy: 0.6398 - val_loss: 0.8336 - val_accuracy: 0.6329
# Epoch 78/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8541 - accuracy: 0.6328
# Epoch 78: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 150ms/step - loss: 0.8239 - accuracy: 0.6441 - val_loss: 0.8334 - val_accuracy: 0.6329
# Epoch 79/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7883 - accuracy: 0.6719
# Epoch 79: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.8487 - accuracy: 0.6441 - val_loss: 0.8332 - val_accuracy: 0.6329
# Epoch 80/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7844 - accuracy: 0.7188
# Epoch 80: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8470 - accuracy: 0.6610 - val_loss: 0.8330 - val_accuracy: 0.6329
# Epoch 81/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8271 - accuracy: 0.6406
# Epoch 81: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.8213 - accuracy: 0.6525 - val_loss: 0.8329 - val_accuracy: 0.6329
# Epoch 82/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8209 - accuracy: 0.6484
# Epoch 82: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.8233 - accuracy: 0.6483 - val_loss: 0.8327 - val_accuracy: 0.6329
# Epoch 83/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8157 - accuracy: 0.6797
# Epoch 83: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.8316 - accuracy: 0.6525 - val_loss: 0.8326 - val_accuracy: 0.6329
# Epoch 84/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8008 - accuracy: 0.6719
# Epoch 84: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.8268 - accuracy: 0.6525 - val_loss: 0.8324 - val_accuracy: 0.6329
# Epoch 85/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8698 - accuracy: 0.6328
# Epoch 85: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 119ms/step - loss: 0.8349 - accuracy: 0.6441 - val_loss: 0.8323 - val_accuracy: 0.6329
# Epoch 86/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8186 - accuracy: 0.6406
# Epoch 86: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 85ms/step - loss: 0.8213 - accuracy: 0.6314 - val_loss: 0.8321 - val_accuracy: 0.6329
# Epoch 87/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8783 - accuracy: 0.6250
# Epoch 87: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8484 - accuracy: 0.6483 - val_loss: 0.8319 - val_accuracy: 0.6329
# Epoch 88/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8412 - accuracy: 0.6328
# Epoch 88: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8291 - accuracy: 0.6568 - val_loss: 0.8317 - val_accuracy: 0.6329
# Epoch 89/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8765 - accuracy: 0.5938
# Epoch 89: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8578 - accuracy: 0.6398 - val_loss: 0.8315 - val_accuracy: 0.6329
# Epoch 90/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8740 - accuracy: 0.6484
# Epoch 90: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8612 - accuracy: 0.6568 - val_loss: 0.8312 - val_accuracy: 0.6329
# Epoch 91/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8280 - accuracy: 0.6172
# Epoch 91: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8317 - accuracy: 0.6483 - val_loss: 0.8311 - val_accuracy: 0.6329
# Epoch 92/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8031 - accuracy: 0.6719
# Epoch 92: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8498 - accuracy: 0.6314 - val_loss: 0.8309 - val_accuracy: 0.6329
# Epoch 93/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8453 - accuracy: 0.6172
# Epoch 93: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8076 - accuracy: 0.6525 - val_loss: 0.8308 - val_accuracy: 0.6329
# Epoch 94/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8055 - accuracy: 0.6328
# Epoch 94: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8198 - accuracy: 0.6525 - val_loss: 0.8307 - val_accuracy: 0.6329
# Epoch 95/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8431 - accuracy: 0.6172
# Epoch 95: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8289 - accuracy: 0.6483 - val_loss: 0.8305 - val_accuracy: 0.6329
# Epoch 96/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8511 - accuracy: 0.6328
# Epoch 96: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 91ms/step - loss: 0.8404 - accuracy: 0.6398 - val_loss: 0.8304 - val_accuracy: 0.6329
# Epoch 97/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8711 - accuracy: 0.6094
# Epoch 97: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8448 - accuracy: 0.6441 - val_loss: 0.8302 - val_accuracy: 0.6329
# Epoch 98/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8221 - accuracy: 0.6797
# Epoch 98: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8305 - accuracy: 0.6398 - val_loss: 0.8299 - val_accuracy: 0.6329
# Epoch 99/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7784 - accuracy: 0.7031
# Epoch 99: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8129 - accuracy: 0.6568 - val_loss: 0.8297 - val_accuracy: 0.6329
# Epoch 100/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8073 - accuracy: 0.6875
# Epoch 100: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8212 - accuracy: 0.6525 - val_loss: 0.8296 - val_accuracy: 0.6329
# Epoch 101/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8184 - accuracy: 0.6562
# Epoch 101: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8142 - accuracy: 0.6568 - val_loss: 0.8295 - val_accuracy: 0.6329
# Epoch 102/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8105 - accuracy: 0.6562
# Epoch 102: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8278 - accuracy: 0.6483 - val_loss: 0.8295 - val_accuracy: 0.6329
# Epoch 103/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8554 - accuracy: 0.6172
# Epoch 103: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8363 - accuracy: 0.6398 - val_loss: 0.8294 - val_accuracy: 0.6329
# Epoch 104/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8634 - accuracy: 0.6016
# Epoch 104: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8417 - accuracy: 0.6441 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 105/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8108 - accuracy: 0.6875
# Epoch 105: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8351 - accuracy: 0.6483 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 106/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8208 - accuracy: 0.6562
# Epoch 106: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8368 - accuracy: 0.6525 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 107/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8074 - accuracy: 0.6328
# Epoch 107: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7951 - accuracy: 0.6483 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 108/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8051 - accuracy: 0.6641
# Epoch 108: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8227 - accuracy: 0.6441 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 109/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7478 - accuracy: 0.7031
# Epoch 109: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8037 - accuracy: 0.6483 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 110/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7916 - accuracy: 0.6641
# Epoch 110: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8156 - accuracy: 0.6441 - val_loss: 0.8294 - val_accuracy: 0.6329
# Epoch 111/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7839 - accuracy: 0.6719
# Epoch 111: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8363 - accuracy: 0.6568 - val_loss: 0.8295 - val_accuracy: 0.6329
# Epoch 112/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7778 - accuracy: 0.6406
# Epoch 112: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.8029 - accuracy: 0.6568 - val_loss: 0.8296 - val_accuracy: 0.6329
# Epoch 113/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8331 - accuracy: 0.6484
# Epoch 113: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8299 - accuracy: 0.6525 - val_loss: 0.8295 - val_accuracy: 0.6329
# Epoch 114/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7582 - accuracy: 0.7031
# Epoch 114: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8073 - accuracy: 0.6525 - val_loss: 0.8293 - val_accuracy: 0.6329
# Epoch 115/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8709 - accuracy: 0.6562
# Epoch 115: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8368 - accuracy: 0.6441 - val_loss: 0.8292 - val_accuracy: 0.6329
# Epoch 116/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8467 - accuracy: 0.6016
# Epoch 116: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8267 - accuracy: 0.6441 - val_loss: 0.8291 - val_accuracy: 0.6329
# Epoch 117/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7213 - accuracy: 0.7031
# Epoch 117: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7948 - accuracy: 0.6568 - val_loss: 0.8290 - val_accuracy: 0.6329
# Epoch 118/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8940 - accuracy: 0.6406
# Epoch 118: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8325 - accuracy: 0.6525 - val_loss: 0.8289 - val_accuracy: 0.6329
# Epoch 119/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8456 - accuracy: 0.6719
# Epoch 119: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8299 - accuracy: 0.6525 - val_loss: 0.8287 - val_accuracy: 0.6329
# Epoch 120/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7983 - accuracy: 0.6719
# Epoch 120: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.8095 - accuracy: 0.6483 - val_loss: 0.8287 - val_accuracy: 0.6329
# Epoch 121/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8142 - accuracy: 0.6484
# Epoch 121: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8144 - accuracy: 0.6525 - val_loss: 0.8287 - val_accuracy: 0.6329
# Epoch 122/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8133 - accuracy: 0.6719
# Epoch 122: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8261 - accuracy: 0.6525 - val_loss: 0.8287 - val_accuracy: 0.6329
# Epoch 123/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7787 - accuracy: 0.6562
# Epoch 123: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8199 - accuracy: 0.6483 - val_loss: 0.8287 - val_accuracy: 0.6329
# Epoch 124/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8806 - accuracy: 0.6328
# Epoch 124: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8375 - accuracy: 0.6441 - val_loss: 0.8286 - val_accuracy: 0.6329
# Epoch 125/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8762 - accuracy: 0.5938
# Epoch 125: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8298 - accuracy: 0.6525 - val_loss: 0.8285 - val_accuracy: 0.6329
# Epoch 126/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8032 - accuracy: 0.6641
# Epoch 126: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.8155 - accuracy: 0.6525 - val_loss: 0.8284 - val_accuracy: 0.6329
# Epoch 127/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8873 - accuracy: 0.6719
# Epoch 127: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8372 - accuracy: 0.6610 - val_loss: 0.8282 - val_accuracy: 0.6329
# Epoch 128/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7860 - accuracy: 0.6484
# Epoch 128: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8303 - accuracy: 0.6483 - val_loss: 0.8281 - val_accuracy: 0.6329
# Epoch 129/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7483 - accuracy: 0.7031
# Epoch 129: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8104 - accuracy: 0.6610 - val_loss: 0.8280 - val_accuracy: 0.6329
# Epoch 130/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7805 - accuracy: 0.6797
# Epoch 130: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8288 - accuracy: 0.6568 - val_loss: 0.8279 - val_accuracy: 0.6329
# Epoch 131/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8675 - accuracy: 0.6328
# Epoch 131: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8466 - accuracy: 0.6525 - val_loss: 0.8278 - val_accuracy: 0.6329
# Epoch 132/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8374 - accuracy: 0.6406
# Epoch 132: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8363 - accuracy: 0.6483 - val_loss: 0.8278 - val_accuracy: 0.6329
# Epoch 133/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8012 - accuracy: 0.6484
# Epoch 133: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8036 - accuracy: 0.6483 - val_loss: 0.8277 - val_accuracy: 0.6329
# Epoch 134/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8032 - accuracy: 0.6641
# Epoch 134: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8236 - accuracy: 0.6441 - val_loss: 0.8276 - val_accuracy: 0.6329
# Epoch 135/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8930 - accuracy: 0.6016
# Epoch 135: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.8216 - accuracy: 0.6525 - val_loss: 0.8275 - val_accuracy: 0.6329
# Epoch 136/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8192 - accuracy: 0.6250
# Epoch 136: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8291 - accuracy: 0.6525 - val_loss: 0.8274 - val_accuracy: 0.6329
# Epoch 137/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8847 - accuracy: 0.6094
# Epoch 137: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8542 - accuracy: 0.6441 - val_loss: 0.8274 - val_accuracy: 0.6329
# Epoch 138/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8714 - accuracy: 0.6641
# Epoch 138: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8360 - accuracy: 0.6483 - val_loss: 0.8272 - val_accuracy: 0.6329
# Epoch 139/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8634 - accuracy: 0.6641
# Epoch 139: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8180 - accuracy: 0.6483 - val_loss: 0.8271 - val_accuracy: 0.6329
# Epoch 140/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8921 - accuracy: 0.6016
# Epoch 140: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8180 - accuracy: 0.6525 - val_loss: 0.8271 - val_accuracy: 0.6329
# Epoch 141/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8326 - accuracy: 0.6406
# Epoch 141: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8180 - accuracy: 0.6525 - val_loss: 0.8271 - val_accuracy: 0.6329
# Epoch 142/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7361 - accuracy: 0.6953
# Epoch 142: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7972 - accuracy: 0.6441 - val_loss: 0.8270 - val_accuracy: 0.6329
# Epoch 143/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8242 - accuracy: 0.6562
# Epoch 143: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8348 - accuracy: 0.6525 - val_loss: 0.8270 - val_accuracy: 0.6329
# Epoch 144/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9023 - accuracy: 0.6484
# Epoch 144: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 84ms/step - loss: 0.8374 - accuracy: 0.6441 - val_loss: 0.8269 - val_accuracy: 0.6329
# Epoch 145/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7382 - accuracy: 0.7422
# Epoch 145: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8247 - accuracy: 0.6568 - val_loss: 0.8268 - val_accuracy: 0.6329
# Epoch 146/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8546 - accuracy: 0.6328
# Epoch 146: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7984 - accuracy: 0.6568 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 147/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7773 - accuracy: 0.6875
# Epoch 147: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.8301 - accuracy: 0.6441 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 148/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7689 - accuracy: 0.6641
# Epoch 148: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8149 - accuracy: 0.6525 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 149/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8185 - accuracy: 0.6719
# Epoch 149: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8191 - accuracy: 0.6525 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 150/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7140 - accuracy: 0.7266
# Epoch 150: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8117 - accuracy: 0.6525 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 151/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8590 - accuracy: 0.6172
# Epoch 151: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8445 - accuracy: 0.6398 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 152/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7837 - accuracy: 0.6641
# Epoch 152: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8047 - accuracy: 0.6568 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 153/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8430 - accuracy: 0.6641
# Epoch 153: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8224 - accuracy: 0.6568 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 154/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8061 - accuracy: 0.6562
# Epoch 154: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7997 - accuracy: 0.6568 - val_loss: 0.8267 - val_accuracy: 0.6329
# Epoch 155/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8421 - accuracy: 0.6484
# ...
# Epoch 268/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8227 - accuracy: 0.6641
# Epoch 268: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8314 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 269/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8091 - accuracy: 0.6484
# Epoch 269: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8007 - accuracy: 0.6525 - val_loss: 0.8216 - val_accuracy: 0.6329
# Epoch 270/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8633 - accuracy: 0.6328
# Epoch 270: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8003 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 271/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8067 - accuracy: 0.6484
# Epoch 271: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8116 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 272/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7648 - accuracy: 0.6797
# Epoch 272: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8088 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 273/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8346 - accuracy: 0.6328
# Epoch 273: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 132ms/step - loss: 0.8130 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 274/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7910 - accuracy: 0.6641
# Epoch 274: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 70ms/step - loss: 0.8095 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 275/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8645 - accuracy: 0.6328
# Epoch 275: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8098 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 276/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8251 - accuracy: 0.6250
# Epoch 276: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7918 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 277/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8028 - accuracy: 0.6641
# Epoch 277: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 69ms/step - loss: 0.8117 - accuracy: 0.6525 - val_loss: 0.8216 - val_accuracy: 0.6329
# Epoch 278/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7871 - accuracy: 0.6719
# Epoch 278: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8037 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 279/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8163 - accuracy: 0.6484
# Epoch 279: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7953 - accuracy: 0.6525 - val_loss: 0.8214 - val_accuracy: 0.6329
# Epoch 280/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7884 - accuracy: 0.6562
# Epoch 280: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8030 - accuracy: 0.6525 - val_loss: 0.8214 - val_accuracy: 0.6329
# Epoch 281/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7597 - accuracy: 0.6719
# Epoch 281: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8108 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 282/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8096 - accuracy: 0.6641
# Epoch 282: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 65ms/step - loss: 0.8216 - accuracy: 0.6525 - val_loss: 0.8214 - val_accuracy: 0.6329
# Epoch 283/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7949 - accuracy: 0.6875
# Epoch 283: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8227 - accuracy: 0.6525 - val_loss: 0.8214 - val_accuracy: 0.6329
# Epoch 284/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7966 - accuracy: 0.6484
# Epoch 284: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7981 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 285/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8271 - accuracy: 0.6406
# Epoch 285: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8275 - accuracy: 0.6525 - val_loss: 0.8216 - val_accuracy: 0.6329
# Epoch 286/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8302 - accuracy: 0.6641
# Epoch 286: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.8192 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 287/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8735 - accuracy: 0.6016
# Epoch 287: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8201 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 288/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9020 - accuracy: 0.6172
# Epoch 288: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 68ms/step - loss: 0.8161 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 289/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8289 - accuracy: 0.6250
# Epoch 289: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8211 - accuracy: 0.6525 - val_loss: 0.8219 - val_accuracy: 0.6329
# Epoch 290/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8249 - accuracy: 0.6719
# Epoch 290: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8206 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 291/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7800 - accuracy: 0.6250
# Epoch 291: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.7895 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 292/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7771 - accuracy: 0.6953
# Epoch 292: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8092 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 293/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8050 - accuracy: 0.6328
# Epoch 293: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8040 - accuracy: 0.6525 - val_loss: 0.8214 - val_accuracy: 0.6329
# Epoch 294/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8441 - accuracy: 0.6250
# Epoch 294: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8159 - accuracy: 0.6525 - val_loss: 0.8213 - val_accuracy: 0.6329
# Epoch 295/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8269 - accuracy: 0.6484
# Epoch 295: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8240 - accuracy: 0.6525 - val_loss: 0.8212 - val_accuracy: 0.6329
# Epoch 296/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8228 - accuracy: 0.6406
# Epoch 296: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8139 - accuracy: 0.6525 - val_loss: 0.8211 - val_accuracy: 0.6329
# Epoch 297/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8199 - accuracy: 0.6875
# Epoch 297: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8303 - accuracy: 0.6525 - val_loss: 0.8211 - val_accuracy: 0.6329
# Epoch 298/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8635 - accuracy: 0.6484
# Epoch 298: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.8168 - accuracy: 0.6525 - val_loss: 0.8211 - val_accuracy: 0.6329
# Epoch 299/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8021 - accuracy: 0.6406
# Epoch 299: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8082 - accuracy: 0.6525 - val_loss: 0.8212 - val_accuracy: 0.6329
# Epoch 300/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8435 - accuracy: 0.6250
# Epoch 300: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8124 - accuracy: 0.6525 - val_loss: 0.8212 - val_accuracy: 0.6329
# Epoch 301/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8966 - accuracy: 0.6094
# Epoch 301: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.8217 - accuracy: 0.6525 - val_loss: 0.8212 - val_accuracy: 0.6329
# Epoch 302/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8022 - accuracy: 0.6562
# Epoch 302: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.8064 - accuracy: 0.6525 - val_loss: 0.8212 - val_accuracy: 0.6329
# Epoch 303/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7499 - accuracy: 0.6953
# Epoch 303: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8119 - accuracy: 0.6525 - val_loss: 0.8213 - val_accuracy: 0.6329
# Epoch 304/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8259 - accuracy: 0.6953
# Epoch 304: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 73ms/step - loss: 0.8176 - accuracy: 0.6525 - val_loss: 0.8213 - val_accuracy: 0.6329
# Epoch 305/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8569 - accuracy: 0.6172
# Epoch 305: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8108 - accuracy: 0.6525 - val_loss: 0.8215 - val_accuracy: 0.6329
# Epoch 306/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8303 - accuracy: 0.6094
# Epoch 306: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8097 - accuracy: 0.6525 - val_loss: 0.8217 - val_accuracy: 0.6329
# Epoch 307/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7744 - accuracy: 0.6562
# Epoch 307: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 83ms/step - loss: 0.8042 - accuracy: 0.6525 - val_loss: 0.8218 - val_accuracy: 0.6329
# Epoch 308/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7815 - accuracy: 0.6797
# Epoch 308: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.8123 - accuracy: 0.6525 - val_loss: 0.8219 - val_accuracy: 0.6329
# Epoch 309/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7815 - accuracy: 0.6719
# Epoch 309: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 81ms/step - loss: 0.7926 - accuracy: 0.6525 - val_loss: 0.8220 - val_accuracy: 0.6329
# Epoch 310/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8195 - accuracy: 0.6484
# Epoch 310: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7962 - accuracy: 0.6525 - val_loss: 0.8221 - val_accuracy: 0.6329
# Epoch 311/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8210 - accuracy: 0.6328
# Epoch 311: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8206 - accuracy: 0.6525 - val_loss: 0.8223 - val_accuracy: 0.6329
# Epoch 312/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8346 - accuracy: 0.6406
# Epoch 312: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8080 - accuracy: 0.6525 - val_loss: 0.8224 - val_accuracy: 0.6329
# Epoch 313/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7967 - accuracy: 0.6562
# Epoch 313: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7986 - accuracy: 0.6525 - val_loss: 0.8226 - val_accuracy: 0.6329
# Epoch 314/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7718 - accuracy: 0.6875
# Epoch 314: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8099 - accuracy: 0.6525 - val_loss: 0.8228 - val_accuracy: 0.6329
# Epoch 315/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8159 - accuracy: 0.6641
# Epoch 315: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8070 - accuracy: 0.6525 - val_loss: 0.8228 - val_accuracy: 0.6329
# Epoch 316/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7996 - accuracy: 0.6406
# Epoch 316: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8147 - accuracy: 0.6525 - val_loss: 0.8231 - val_accuracy: 0.6329
# Epoch 317/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7382 - accuracy: 0.6719
# Epoch 317: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 89ms/step - loss: 0.8079 - accuracy: 0.6525 - val_loss: 0.8232 - val_accuracy: 0.6329
# Epoch 318/1000
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8274 - accuracy: 0.6719
# Epoch 318: saving model to model/point_history_classifier\point_history_classifier.hdf5
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8144 - accuracy: 0.6525 - val_loss: 0.8231 - val_accuracy: 0.6329
# Epoch 318: early stopping

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 1s 577ms/step
# [1.16301635e-05 2.37764289e-05 5.32544814e-02 6.19195342e-01
#  3.27326357e-01 1.39643103e-04 4.87303114e-05]
# 3

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         5
#            3       0.63      1.00      0.78        50
#            4       0.00      0.00      0.00        24
#
#     accuracy                           0.63        79
#    macro avg       0.21      0.33      0.26        79
# weighted avg       0.40      0.63      0.49        79
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
model = tf.keras.models.load_model(model_save_path)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
tflite_save_path = 'model/point_history_classifier/point_history_classifier.tflite'

# %%
# モデルを変換(量子化
converter = tf.lite.TFLiteConverter.from_keras_model(model)  # converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\91999\AppData\Local\Temp\tmpkmamh6bh\assets
# INFO:tensorflow:Assets written to: C:\Users\91999\AppData\Local\Temp\tmpkmamh6bh\assets
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\3967824984.py in <module>
#       2 converter = tf.lite.TFLiteConverter.from_keras_model(model)  # converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
#       3 converter.optimizations = [tf.lite.Optimize.DEFAULT]
# ----> 4 tflite_quantized_model = converter.convert()
#       5
#       6 open(tflite_save_path, 'wb').write(tflite_quantized_model)
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\lite.py in wrapper(self, *args, **kwargs)
#     931   def wrapper(self, *args, **kwargs):
#     932     # pylint: disable=protected-access
# --> 933     return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#     934     # pylint: enable=protected-access
#     935
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\lite.py in _convert_and_export_metrics(self, convert_func, *args, **kwargs)
#     909     self._save_conversion_params_metric()
#     910     start_time = time.process_time()
# --> 911     result = convert_func(self, *args, **kwargs)
#     912     elapsed_time_ms = (time.process_time() - start_time) * 1000
#     913     if result:
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\lite.py in convert(self)
#    1340         Invalid quantization parameters.
#    1341     """
# -> 1342     saved_model_convert_result = self._convert_as_saved_model()
#    1343     if saved_model_convert_result:
#    1344       return saved_model_convert_result
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\lite.py in _convert_as_saved_model(self)
#    1323       if self.saved_model_dir:
#    1324         return super(TFLiteKerasModelConverterV2,
# -> 1325                      self).convert(graph_def, input_tensors, output_tensors)
#    1326     finally:
#    1327       shutil.rmtree(temp_dir, True)
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\lite.py in convert(self, graph_def, input_tensors, output_tensors)
#    1137         input_tensors=input_tensors,
#    1138         output_tensors=output_tensors,
# -> 1139         **converter_kwargs)
#    1140
#    1141     return self._optimize_tflite_model(
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\convert_phase.py in wrapper(*args, **kwargs)
#     210         else:
#     211           report_error_message(str(converter_error))
# --> 212         raise converter_error from None  # Re-throws the exception.
#     213       except Exception as error:
#     214         report_error_message(str(error))
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\convert_phase.py in wrapper(*args, **kwargs)
#     203     def wrapper(*args, **kwargs):
#     204       try:
# --> 205         return func(*args, **kwargs)
#     206       except ConverterError as converter_error:
#     207         if converter_error.errors:
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\convert.py in convert_graphdef(input_data, input_tensors, output_tensors, **kwargs)
#     796       input_data.SerializeToString(),
#     797       debug_info_str=debug_info.SerializeToString() if debug_info else None,
# --> 798       enable_mlir_converter=enable_mlir_converter)
#     799   return data
#     800
#
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\lite\python\convert.py in convert(model_flags_str, conversion_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     308       for error_data in _metrics_wrapper.retrieve_collected_errors():
#     309         converter_error.append_error(error_data)
# --> 310       raise converter_error
#     311
#     312   return _run_deprecated_conversion_binary(model_flags_str,
#
# ConverterError: c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\python\saved_model\save.py:1267:0: error: 'tf.TensorListReserve' op requires element_shape to be static during TF Lite transformation pass
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# c:\Users\91999\Documents\RP\Model test\.venv\lib\site-packages\tensorflow\python\saved_model\save.py:1267:0: error: failed to legalize operation 'tf.TensorListReserve' that was explicitly marked illegal
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: error: Lowering tensor list ops is failed. Please consider using Select TF ops and disabling `_experimental_lower_tensor_list_ops` flag in the TFLite converter object. For example, converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]\n converter._experimental_lower_tensor_list_ops = False

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details)
# Out:
# [{'name': 'input_1', 'index': 0, 'shape': array([ 1, 32]), 'shape_signature': array([-1, 32]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [0.9579909  0.01342559 0.00907356 0.01950999]
# 0
